# %% [markdown]
# <a href="https://colab.research.google.com/github/fdmy2713-dotcom/ADS1/blob/main/ADS1_Tutorial_3_Matplotlib_Worksheet1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Student Worksheet
#
# This worksheet contains **10 hands-on exercises** to practice Matplotlib along with core Python libraries like **NumPy** and **pandas**. Each exercise has:
#
# - A **Markdown cell** describing the task
# - An empty **code cell** with TODOs for you to complete
#
# > Tip: Run the very first code cell to import libraries before starting.

# %%
# 🚀 Run this cell first (libraries + sample data helpers)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Inline plotting for Jupyter and Google Colab
# %matplotlib inline

# Utility: deterministic randomness
rng = np.random.default_rng(42)

print('Libraries ready! NumPy:', np.__version__, '| pandas:', pd.__version__)
# Out:
# Libraries ready! NumPy: 2.0.2 | pandas: 2.2.2

# %% [markdown]
# ## Exercise 1 — First Line Plot
# Create a simple line plot of `x = [0,1,2,3,4]` vs `y = [0,1,4,9,16]`.
#
# **Goals:**
# - Use `plt.plot(x, y)`
# - Add a title and axis labels
# - Call `plt.show()` to display the figure

# %%
# TODO: Make a basic line plot with labels and title
x = [0,1,2,3,4]
y = [0,1,4,9,16]

# Your code here:
plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title(" X vs Y")
#plt.show() - no need to use this if "%matplotlib inline" is used
# Out:
# Text(0.5, 1.0, ' X vs Y')

# %%
help(plt.plot)

# %% [markdown]
# ## Exercise 2 — Style Your Plot
# Plot the same data as Exercise 1 but:
# - Change line color to `'green'`
# - Use a dashed linestyle (`'--'`)
# - Set linewidth to `3`
#
# **Hint:** Change the parameters of`plt.plot(x, y, color='green', linestyle='--', linewidth=3)`

# %%
# TODO: Style the line (color, linestyle, linewidth) and show the plot
x = [0,1,2,3,4]
y = [0,1,4,9,16]

# Your code here
# plt.plot(...)
# plt.show()

# TODO: Style the line (color, linestyle, linewidth) and show the plot
plt.plot(x, y, color="blue", linestyle="--", linewidth=2, marker="o", label="y = x²")
plt.title("Styled Line Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 3 — Multiple Lines & Legend
# Plot two lines on the same axes:
# - `y1 = x`
# - `y2 = x**2`
#
# **Goals:**
# - Plot both lines with different styles
# - Add a legend (use `label=` in `plt.plot` and `plt.legend()`)
# - Add grid lines (`plt.grid(True)`)

# %%
# TODO: Plot two lines with legend and grid
x = np.arange(0, 6)
y1 = x
y2 = x**2

# Your code here
# plt.plot(..., label='linear')
# plt.plot(..., label='quadratic')
# plt.legend()
# plt.grid(True)
# plt.show()

# TODO: Plot two lines with legend and grid
plt.plot(x, y1, label="linear", color="blue", linestyle="-", linewidth=2)
plt.plot(x, y2, label="quadratic", color="red", linestyle="--", linewidth=2)

plt.legend()
plt.grid(True)
plt.title("Linear vs Quadratic")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## Exercise 4 — Scatter Plot & Markers
# Generate 50 random points around a line `y = 2x + 1` with some noise.
#
# **Goals:**
# - Create `x` uniformly in `[0, 10]`
# - Create `y = 2x + 1 + noise` where `noise ~ Normal(0, 2)`
# - Use `plt.scatter` with a marker style of your choice (e.g., `'o'`)
# - Label axes and title

# %%
# TODO: Make a scatter plot with random data and noise
n = 50
x = rng.uniform(0, 10, size=n)
noise = rng.normal(0, 2, size=n)
y = 2*x + 1 + noise

# Your code here
# plt.scatter(...)
# plt.xlabel(...); plt.ylabel(...)
# plt.title(...)
# plt.show()

# TODO: Make a scatter plot with random data and noise
plt.scatter(x, y, color="blue", alpha=0.7, edgecolor="k", label="Data with noise")

plt.xlabel("x values")
plt.ylabel("y values")
plt.title("Scatter Plot with Random Data and Noise")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 5 — Bar Chart
# Create a bar chart of daily sales:
#
# Days = `['Mon','Tue','Wed','Thu','Fri']`
# Sales = `[12, 18, 9, 14, 20]`
#
# **Goals:**
# - Use `plt.bar`
# - Rotate x-tick labels by 0 or 45 degrees as you like
# - Add value labels on top of bars (optional)

# %%
# TODO: Create a bar chart of weekly sales
labels = ['Mon','Tue','Wed','Thu','Fri']
values = [12, 18, 9, 14, 20]

# Your code here
# plt.bar(...)
# for i, v in enumerate(values):
#     plt.text(i, v + 0.3, str(v), ha='center')
# plt.show()

# TODO: Create a bar chart of weekly sales
plt.bar(labels, values, color="skyblue", edgecolor="black")

# Add value labels above bars
for i, v in enumerate(values):
    plt.text(i, v + 0.3, str(v), ha='center', fontsize=10)

plt.xlabel("Day of the Week")
plt.ylabel("Sales")
plt.title("Weekly Sales")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ## Exercise 6 — Histogram
# Generate 1000 samples from a normal distribution with mean 0 and std 1.
#
# **Goals:**
# - Plot a histogram with 30 bins
# - Show density (probability) instead of counts (`density=True`)
# - Add a vertical line at the mean

# %%
# TODO: Histogram with density
samples = rng.normal(0, 1, size=1000)

# Your code here
# plt.hist(samples, bins=30, density=True)
# plt.axvline(samples.mean(), linestyle='--')
# plt.title('Normal(0,1) Histogram')
# plt.show()

# TODO: Histogram with density
plt.hist(samples, bins=30, density=True, color="skyblue", edgecolor="black", alpha=0.7)

# Add vertical line at the mean
plt.axvline(samples.mean(), color="red", linestyle="--", linewidth=2, label=f"Mean = {samples.mean():.2f}")

plt.title("Normal(0,1) Histogram")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# ## Exercise 7 — Subplots
# Create a figure with **two subplots (1 row, 2 columns)**:
# - Left: `sin(x)`
# - Right: `cos(x)`
#
# **Goals:**
# - Use `plt.subplots(1, 2, figsize=(10,4))`
# - Plot on each axis separately
# - Add titles to each subplot

# %%
# TODO: Subplots of sin and cos
x = np.linspace(0, 2*np.pi, 200)
ysin = np.sin(x)
ycos = np.cos(x)

# fig, axes = plt.subplots(1, 2, figsize=(10, 4))
# ax1, ax2 = axes
# ax1.plot(...); ax1.set_title('sin(x)')
# ax2.plot(...); ax2.set_title('cos(x)')
# plt.show()

# TODO: Subplots of sin and cos
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

ax1, ax2 = axes
ax1.plot(x, ysin, color="blue", linewidth=2)
ax1.set_title("sin(x)")
ax1.set_xlabel("x")
ax1.set_ylabel("sin(x)")
ax1.grid(True)

ax2.plot(x, ycos, color="red", linestyle="--", linewidth=2)
ax2.set_title("cos(x)")
ax2.set_xlabel("x")
ax2.set_ylabel("cos(x)")
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 8 — Pie Chart
# Visualize category shares with a pie chart:
#
# Labels = `['A','B','C','D']`
# Sizes = `[30, 25, 20, 25]`
#
# **Goals:**
# - Use `plt.pie`
# - Add `autopct='%1.1f%%'`
# - Optionally `explode` one slice
# - Make the chart a circle using `plt.axis('equal')`

# %%
# TODO: Create a pie chart with labels and percentages
labels = ['A','B','C','D']
sizes = [30, 25, 20, 25]
explode = [0.05, 0, 0, 0]  # optional

# Your code here
# plt.pie(...)
# plt.axis('equal')
# plt.title('Category Shares')
# plt.show()

# TODO: Create a pie chart with labels and percentages
plt.pie(sizes,labels=labels,autopct='%1.1f%%',explode=explode,shadow=True,startangle=90)

plt.axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle
plt.title("Category Shares")
plt.show()

# %% [markdown]
# ## Exercise 9 — Using pandas with Matplotlib
# Create a small `pandas` DataFrame of monthly temperatures and plot it.
#
# **Data:**
# ```
# Month: Jan Feb Mar Apr May Jun
# Temp:  26  28  29  30  31  32
# ```
#
# **Goals:**
# - Build the DataFrame
# - Plot a line chart of Temp vs Month using either `plt.plot` or `df.plot`
# - Label axes and rotate tick labels

# %%
# TODO: Build a DataFrame and plot Temp vs Month
months = ['Jan','Feb','Mar','Apr','May','Jun']
temps = [26, 28, 29, 30, 31, 32]

# df = pd.DataFrame({...})
# Option A: plt.plot(months, temps)
# Option B: df.plot(x='Month', y='Temp')
# plt.show()

# TODO: Build a DataFrame and plot Temp vs Month
df = pd.DataFrame({
    "Month": months,
    "Temp": temps
})

# Option A: Using matplotlib directly
plt.plot(months, temps, marker="o", color="blue", label="Temperature")
plt.title("Monthly Temperatures")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.grid(True)
plt.show()

# Option B: Using pandas built-in plotting
df.plot(x="Month", y="Temp", marker="o", color="red", legend=True, grid=True, title="Monthly Temperatures")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# ## Exercise 10 — Fill Between (Confidence Band)
# Simulate a noisy signal and a 1-σ confidence band.
#
# **Goals:**
# - Create `x` from 0 to 10 (200 points)
# - Let `y = sin(x) + noise` with noise `~ Normal(0, 0.2)`
# - Let `sigma = 0.3`
# - Plot the line and fill the area between `y - sigma` and `y + sigma` using `plt.fill_between`

# %%
# TODO: Plot a line with a confidence band using fill_between
x = np.linspace(0, 10, 200)
noise = rng.normal(0, 0.2, size=x.size)
y = np.sin(x) + noise
sigma = 0.3

# Your code here
# plt.plot(x, y, label='signal')
# plt.fill_between(x, y - sigma, y + sigma, alpha=0.3, label='±1σ')
# plt.legend()
# plt.show()

# TODO: Plot a line with a confidence band using fill_between
plt.plot(x, y, label="signal", color="blue")
plt.fill_between(x, y - sigma, y + sigma, alpha=0.3, color="blue", label="±1σ")

plt.title("Signal with Confidence Band")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
