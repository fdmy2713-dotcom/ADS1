# %% [markdown]
# <a href="https://colab.research.google.com/github/fdmy2713-dotcom/ADS1/blob/main/ADS1_Unit09_Tutorial_9_2_Colab_Markdown_Styling_Guide_Exercises_Color_IPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Markdown & Styling Guide — Color

# %% [markdown]
# ## Coloring Text in Google Colab
# Colab supports HTML and LaTeX color syntax for highlighting text and math.

# %% [markdown]
# ### 🎨 HTML Colors in Markdown
# Use `<span>` or `<h3>` with inline CSS styles.
#
# ```markdown
# <span style="color:red">Red</span>, <span style="color:blue">Blue</span>, <span style="color:green">Green</span>
# ```
#
# ✅ Output:
#
# <span style="color:red">Red</span>, <span style="color:blue">Blue</span>, <span style="color:green">Green</span>

# %% [markdown]
# ### 🟡 Background Highlighting
# ```markdown
# <span style="background-color:yellow; color:black;">Important highlighted note</span>
# ```
# ✅ Output:
#
# <span style="background-color:yellow; color:black;">Important highlighted note</span>

# %% [markdown]
# ### 💜 Colored Headings
# ```markdown
# <h3 style="color:purple; text-align:center;">Important Notice</h3>
# ```
# ✅ Output:
# <h3 style="color:purple; text-align:center;">Important Notice</h3>

# %% [markdown]
# ### 🧮 Colors in LaTeX Math
# ```markdown
# Inline math: $E = \color{red}{mc^2}$
#
# Display math:
# $$
# \color{blue}{\int_0^1 x^2\,dx = \tfrac{1}{3}}
# $$
# ```
# ✅ Output:
#
# Inline → \(E = \color{red}{mc^2}\)
#
# Display →
# $$
# \color{blue}{\int_0^1 x^2\,dx = \tfrac{1}{3}}
# $$

# %% [markdown]
# ### 🧩 Python Code Output Colors
# ```python
# print("\033[31mRed text\033[0m")
# print("\033[32mGreen text\033[0m")
# print("\033[34mBlue text\033[0m")
# ```
# ✅ Output (console): Red, Green, Blue lines in color.
