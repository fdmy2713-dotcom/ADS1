# %% [markdown]
# <a href="https://colab.research.google.com/github/fdmy2713-dotcom/ADS1/blob/main/ADS1_Unit09_Tutorial_9_1_Colab_Markdown_Styling_Guide_with_Exercises_IPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Markdown & Styling Guide — With Hands‑On Exercises
#
# > **How to use**: Work through Sections 1–12 briefly, then complete **Section 13: Hands‑On Practice**.

# %% [markdown]
# ## 1. Basic Text Formatting
# - *Italic* → `*text*`
# - **Bold** → `**text**`
# - ***Bold + Italic*** → `***text***`
# - `Inline code` → `` `len(x)` ``
# - ~~Strikethrough~~ → `~~text~~`

# %% [markdown]
# ## 2. Headings
#
# `#`, `##`, `###`, `####`
#
# # H1 Example
# ## H2 Example
# ### H3 Example
# #### H4 Example

# %% [markdown]
# ## 3. Lists
#
# - Bullet 1
#   - Sub-bullet
# - Bullet 2
#
# 1. Step one
# 2. Step two
#    1. Sub-step

# %% [markdown]
# ## 4. Code Blocks
#
# Inline code: `` `sum(range(5))` ``
#
# Fenced block:
# ```python
# for i in range(3):
#     print(i)
# ```

# %%
# Demo code
for i in range(3):
    print(f'Hello {i}')
# Out:
# Hello 0
# Hello 1
# Hello 2

# %% [markdown]
# ## 5. Links & Images
#
# Link: `[Project Jupyter](https://jupyter.org)` → [Project Jupyter](https://jupyter.org)
#
# Image:
# ```markdown
# ![Placeholder](https://via.placehold.co/150x100)
# ```
# ![Placeholder](https://via.placehold.co/150x100)

# %% [markdown]
# ## 6. Tables
#
# ```markdown
# | Name | Score |
# |------|-------|
# | Alice | 85 |
# | Bob | 90 |
# ```
#
# | Name | Score |
# |------|-------|
# | Alice | 85 |
# | Bob | 90 |

# %% [markdown]
# ## 7. Blockquotes & Horizontal Rules
#
# > **Note:** Use blockquotes for tips.
#
# ---
#
# Above is a horizontal rule.

# %% [markdown]
# ## 8. LaTeX Math
#
# Inline: `$E=mc^2$` → $E=mc^2$
#
# Block:
# $$
# \int_0^\infty e^{-x}\,dx = 1
# $$

# %% [markdown]
# ## 9. Collapsible Sections (Colab-supported)
#
# Use HTML `<details>`:
#
# <details>
# <summary>Click to expand</summary>
#
# Hidden bullet 1
#
# ```python
# def hidden():
#     return 'Surprise!'
# ```
#
# </details>

# %% [markdown]
# ## 10. Task Lists
#
# - [x] Explain headings
# - [ ] Add your own section

# %% [markdown]
# ## 11. HTML Callout (optional)
#
# <div style="border:1px solid #ccc; padding:8px; border-radius:8px;">
# <strong>Callout:</strong> You can style small boxes with inline HTML.
# </div>

# %% [markdown]
# ## 12. Quick Reference
#
# - *Italic* `*text*` · **Bold** `**text**` · Code `` `code` ``
# - Link `[text](url)` · Image `![alt](url)`
# - Table pipes + header divider
# - Math `$inline$` & `$$block$$`
# - Collapsible `<details>` blocks
# - Task list `- [ ]`/`- [x]`

# %% [markdown]
# ## 13. Hands‑On Practice
# ***Upload your completed script to your Github.***
#
# **Task:** Create a single Markdown section that uses **every** core feature below. Keep it short but complete.
#
# **Include all of the following in one coherent mini‑report:**
# 1. A top‑level heading and a sub‑heading
# 2. A short paragraph with *italic*, **bold**, and `inline code`
# 3. A bulleted list **and** a numbered list (one sub‑item somewhere)
# 4. A fenced Python code block
# 5. One link and one image (use any valid URL)
# 6. A table with 2 columns and 2 rows
# 7. A blockquote and a horizontal rule
# 8. One inline LaTeX equation (Normal PDF) and one display equation (Normal CDF)
# 9. A collapsible `<details>` section containing at least one bullet
# 10. A task list with one checked and one unchecked box
# 11. An HTML callout box (simple `<div>` with a border)
#
# > **Instructions**: Duplicate the Markdown cell below (right‑click → *Copy cell* → *Paste cell below*) and replace the placeholders. Keep the heading `### PRACTICE SUBMISSION`

# %% [markdown]
# ### PRACTICE SUBMISSION (Put your codes here)
#
# Write your mini‑report here using the 11 requirements above.
# ### PRACTICE SUBMISSION
#
# # Python Essentials: A Mini Technical Summary
# ## Exploring Core Features and Markdown Presentation
#
# Python is a *widely adopted*, **high-level** programming language known for its clarity and `readability`.
# Its design philosophy emphasizes code simplicity, enabling both beginners and professionals to work efficiently.
#
# ---
#
# ### Key Highlights
#
# - Readable and maintainable syntax
# - Extensive library support
# - Active open-source community
#
# 1. Foundational Concepts
#    1. Data types and variables
# 2. Control flow and modular programming
# 3. Automation and analytics applications
#
# ```python
# # Example: Simple Function in Python
# def compute_area(radius):
#     pi = 3.1416
#     return pi * (radius ** 2)
#
# print("Area:", compute_area(5))
# ````
#
# [Visit the Official Python Website](https://www.python.org)
#
# ![Python Logo](https://www.python.org/static/community_logos/python-logo.png)
#
#
# | Concept  | Example              |
# | -------- | -------------------- |
# | Variable | `x = 10`             |
# | Loop     | `for i in range(5):` |
#
# > “Simplicity is the soul of efficiency.”
# > — Austin Freeman
#
# ---
#
# Inline Equation: ( E = mc^2 )
# Display Equation:
# [
# F(x) = P(X \le x) = \int_{-\infty}^{x} f(t),dt
# ]
#
# <details>
#   <summary>Additional Notes</summary>
#   - Maintain consistent indentation in code
#   - Use meaningful variable names
#   - Document your work clearly
# </details>
#
# ### Task Progress
#
# * [x] Completed Markdown formatting
# * [ ] Submit for review
#
# <div style="border:2px solid #4682B4; background-color:#F8FAFC; padding:10px; border-radius:10px;">
# <strong>Note:</strong> Consistent documentation practices enhance both readability and collaboration in technical projects.
# </div>
# ```
#
# ---

# %% [markdown]
# ## Explanation of Markdown Features (1 – 11)
#
# **1. Top-level heading and sub-heading**
#
# * `# Python Essentials: A Mini Technical Summary` → top-level heading
# * `## Exploring Core Features and Markdown Presentation` → sub-heading
#
# ---
#
# **2. Paragraph with italic, bold, and inline code**
#
# * The paragraph:
#
#   > Python is a *widely adopted*, **high-level** programming language known for its clarity and `readability`.
# * Uses all three formats:
#
#   * *italic* → emphasizes a word
#   * **bold** → highlights importance
#   * `inline code` → displays a code term in monospace
#
# ---
#
# **3. Bulleted list and numbered list (with a sub-item)**
#
# * **Bulleted list:**
#
#   ```markdown
#   - Readable and maintainable syntax
#   - Extensive library support
#   - Active open-source community
#   ```
# * **Numbered list with a sub-item:**
#
#   ```markdown
#   1. Foundational Concepts
#      1. Data types and variables
#   2. Control flow and modular programming
#   ```
#
# ---
#
# **4. Fenced Python code block**
#
# * Uses triple backticks and a language tag (` ```python `) for syntax highlighting:
#
#   ```python
#   def compute_area(radius):
#       pi = 3.1416
#       return pi * (radius ** 2)
#   print("Area:", compute_area(5))
#   ```
#
# ---
#
# **5. Link and image (valid URLs)**
#
# * **Link:** `[Visit the Official Python Website](https://www.python.org)`
# * **Image:** `![Python Logo](https://www.python.org/static/community_logos/python-logo.png)`
#
# ---
#
# **6. Table with 2 columns and 2 rows**
#
# ```markdown
# | Concept | Example |
# |----------|----------|
# | Variable | `x = 10` |
# | Loop     | `for i in range(5):` |
# ```
#
# ---
#
# **7. Blockquote and horizontal rule**
#
# * **Blockquote:**
#
#   > “Simplicity is the soul of efficiency.” — Austin Freeman
# * **Horizontal rule:**
#   `---` creates a clean line separator.
# Separates content sections visually and adds citation.
#
# ---
#
# **8. Inline and display LaTeX equations**
#
# * **Inline:** `\( E = mc^2 \)` → renders inside text.
# * **Display (Normal CDF):**
#
#   ```markdown
#   \[
#   F(x) = P(X \le x) = \int_{-\infty}^{x} f(t)\,dt
#   \]
#   ```
#
# ---
#
# **9. Collapsible `<details>` section (with a bullet)**
#
# ```markdown
# <details>
#   <summary>Additional Notes</summary>
#   - Maintain consistent indentation in code
# </details>
# ```
#
# Allows the reader to expand or hide extra information neatly.
#
# ---
#
# **10. Task list (one checked and one unchecked box)**
#
# ```markdown
# - [x] Completed Markdown formatting
# - [ ] Submit for review
# ```
#
# Shows progress tracking directly in Markdown.
#
# ---
#
# **11. HTML callout box (with border styling)**
#
# ```html
# <div style="border:2px solid #4682B4; background-color:#F8FAFC; padding:10px; border-radius:10px;">
# 📘 <strong>Note:</strong> Consistent documentation practices enhance both readability and collaboration.
# </div>
# ```
#
# ---
